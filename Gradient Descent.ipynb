# %%
from sklearn.datasets import load_svmlight_file
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import os
import math
import time

def rmse(x,y,theta):
    hypothesis = np.dot(x,theta)
    cost = np.average((y-hypothesis) ** 2)
    rmse = (math.sqrt(cost))
    return rmse
    




dir_list = os.listdir('C:\\Users\\saikiran\\Downloads\\dataset')
#print(len(dir_list))
with open('C:\\Users\\saikiran\\Downloads\\dataset_combined\\combined.txt', 'w') as outfile:
    for fname in dir_list:
        with open('C:\\Users\\saikiran\\Downloads\\dataset\\'+fname) as infile:
            for line in infile:
                outfile.write(line)
    
data = load_svmlight_file('C:\\Users\\saikiran\\Downloads\\dataset_combined\\combined.txt')
X = data[0]
X = X[:2000]
X = X.toarray()
bias = np.ones((len(X),1), dtype=int)
X = np.concatenate((bias,X),axis=1)
Y = data[1]
Y = Y[:2000]
Y = Y.reshape(len(Y),1)

np.random.seed(0)
#beta = np.random.rand(X.shape[1],1)
#beta = np.random.uniform(0.00005,0.0001,X.shape[1])
beta = np.random.uniform(0.001,0.01,X.shape[1])
beta = beta.reshape(len(beta),1)
#beta = np.around(beta, decimals=3)
alpha = 0.0000000001

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30, random_state=42)
Rmse_train_list =[]
Rmse_test_list =[]
start = time.time()
for i in range (0,100):
    for i in range(len(X_train)):
        hypothesis = np.dot(X_train, beta)
        gradient =  np.dot(X_train.T,(Y_train-hypothesis))
        beta = beta + np.multiply(alpha,gradient)
    RMSE_train = rmse(X_train,Y_train,beta)
    RMSE_test = rmse(X_test,Y_test,beta)
    Rmse_train_list = np.append(Rmse_train_list,RMSE_train)
    Rmse_test_list = np.append(Rmse_test_list,RMSE_test)

end = time.time() 
print("execution time is:", end-start)
for i in range (len(Rmse_train_list)):
    if i==0:
        print("epoch={} and total train_RMSE={}".format(i,Rmse_train_list[i]))
    else:
        rmse_diff =abs(Rmse_train_list[i]-Rmse_train_list[i-1])
        if rmse_diff<0.01:
            print("converged at epoch={}".format(i))
            break
        else:
            print("epoch={} and total train_RMSE={}".format(i,Rmse_train_list[i]))
for i in range (len(Rmse_train_list)):
        print("epoch={} and total test_RMSE={}".format(i,Rmse_test_list[i]))
# Out:
# execution time is: 142.23327589035034
# epoch=0 and total train_RMSE=0.8859985149533989
# epoch=1 and total train_RMSE=0.6158354461680486
# epoch=2 and total train_RMSE=0.528052011043369
# epoch=3 and total train_RMSE=0.4858771693640553
# epoch=4 and total train_RMSE=0.45962079972213343
# epoch=5 and total train_RMSE=0.4407304718665796
# epoch=6 and total train_RMSE=0.4260324773682253
# epoch=7 and total train_RMSE=0.41409604237287484
# converged at epoch=8
# epoch=0 and total test_RMSE=7.255635701861254
# epoch=1 and total test_RMSE=5.920243614021352
# epoch=2 and total test_RMSE=5.286510555665047
# epoch=3 and total test_RMSE=4.989109707958682
# epoch=4 and total test_RMSE=4.8437578985535685
# epoch=5 and total test_RMSE=4.763239058942228
# epoch=6 and total test_RMSE=4.7095500766147
# epoch=7 and total test_RMSE=4.66703613543977
# epoch=8 and total test_RMSE=4.629514593228871
# epoch=9 and total test_RMSE=4.59463848035726
# epoch=10 and total test_RMSE=4.5615469594044615
# epoch=11 and total test_RMSE=4.529920905379794
# epoch=12 and total test_RMSE=4.499619473528489
# epoch=13 and total test_RMSE=4.470549817559807
# epoch=14 and total test_RMSE=4.442626506310405
# epoch=15 and total test_RMSE=4.4157629783134
# epoch=16 and total test_RMSE=4.389872779151742
# epoch=17 and total test_RMSE=4.364872605891382
# epoch=18 and total test_RMSE=4.34068472207332
# epoch=19 and total test_RMSE=4.317238305809569
# epoch=20 and total test_RMSE=4.294469911207634
# epoch=21 and total test_RMSE=4.272323338076104
# epoch=22 and total test_RMSE=4.25074916156453
# epoch=23 and total test_RMSE=4.229704098861424
# epoch=24 and total test_RMSE=4.209150324920978
# epoch=25 and total test_RMSE=4.189054802020859
# epoch=26 and total test_RMSE=4.169388656927094
# epoch=27 and total test_RMSE=4.150126620340613
# epoch=28 and total test_RMSE=4.13124653222406
# epoch=29 and total test_RMSE=4.112728910623894
# epoch=30 and total test_RMSE=4.094556578706613
# epoch=31 and total test_RMSE=4.076714343622689
# epoch=32 and total test_RMSE=4.059188720692251
# epoch=33 and total test_RMSE=4.041967696789425
# epoch=34 and total test_RMSE=4.0250405274074
# epoch=35 and total test_RMSE=4.008397562557095
# epoch=36 and total test_RMSE=3.99203009730772
# epoch=37 and total test_RMSE=3.9759302433778467
# epoch=38 and total test_RMSE=3.960090818716403
# epoch=39 and total test_RMSE=3.9445052524728177
# epoch=40 and total test_RMSE=3.9291675031476014
# epoch=41 and total test_RMSE=3.9140719880478456
# epoch=42 and total test_RMSE=3.8992135224527646
# epoch=43 and total test_RMSE=3.884587267131431
# epoch=44 and total test_RMSE=3.8701886830541437
# epoch=45 and total test_RMSE=3.8560134923073104
# epoch=46 and total test_RMSE=3.842057644363784
# epoch=47 and total test_RMSE=3.8283172869809046
# epoch=48 and total test_RMSE=3.8147887411006316
# epoch=49 and total test_RMSE=3.8014684792129225
# epoch=50 and total test_RMSE=3.788353106717627
# epoch=51 and total test_RMSE=3.77543934588326
# epoch=52 and total test_RMSE=3.762724022055441
# epoch=53 and total test_RMSE=3.7502040518141224
# epoch=54 and total test_RMSE=3.7378764328188416
# epoch=55 and total test_RMSE=3.725738235115721
# epoch=56 and total test_RMSE=3.713786593709703
# epoch=57 and total test_RMSE=3.7020187022312716
# epoch=58 and total test_RMSE=3.690431807549232
# epoch=59 and total test_RMSE=3.679023205200466
# epoch=60 and total test_RMSE=3.667790235524291
# epoch=61 and total test_RMSE=3.6567302804038424
# epoch=62 and total test_RMSE=3.6458407605293552
# epoch=63 and total test_RMSE=3.6351191331094683
# epoch=64 and total test_RMSE=3.6245628899662274
# epoch=65 and total test_RMSE=3.61416955595785
# epoch=66 and total test_RMSE=3.603936687680684
# epoch=67 and total test_RMSE=3.593861872408161
# epoch=68 and total test_RMSE=3.5839427272301765
# epoch=69 and total test_RMSE=3.574176898361057
# epoch=70 and total test_RMSE=3.56456206058872
# epoch=71 and total test_RMSE=3.555095916841289
# epoch=72 and total test_RMSE=3.545776197850513
# epoch=73 and total test_RMSE=3.5366006618944494
# epoch=74 and total test_RMSE=3.527567094604133
# epoch=75 and total test_RMSE=3.5186733088211275
# epoch=76 and total test_RMSE=3.5099171444949304
# epoch=77 and total test_RMSE=3.501296468610583
# epoch=78 and total test_RMSE=3.492809175138432
# epoch=79 and total test_RMSE=3.4844531849991847
# epoch=80 and total test_RMSE=3.4762264460385257
# epoch=81 and total test_RMSE=3.4681269330064093
# epoch=82 and total test_RMSE=3.4601526475370408
# epoch=83 and total test_RMSE=3.452301618126274
# epoch=84 and total test_RMSE=3.44457190010368
# epoch=85 and total test_RMSE=3.436961575597138
# epoch=86 and total test_RMSE=3.4294687534882757
# epoch=87 and total test_RMSE=3.4220915693573954
# epoch=88 and total test_RMSE=3.414828185416923
# epoch=89 and total test_RMSE=3.4076767904326464
# epoch=90 and total test_RMSE=3.4006355996323396
# epoch=91 and total test_RMSE=3.393702854601509
# epoch=92 and total test_RMSE=3.386876823166169
# epoch=93 and total test_RMSE=3.380155799262683
# epoch=94 and total test_RMSE=3.3735381027949596
# epoch=95 and total test_RMSE=3.3670220794792054
# epoch=96 and total test_RMSE=3.3606061006766144
# epoch=97 and total test_RMSE=3.3542885632144843
# epoch=98 and total test_RMSE=3.3480678891961544
# epoch=99 and total test_RMSE=3.3419425258003974

# %%
epoch = np.arange(100)
plt.plot(epoch,Rmse_train_list)
plt.plot(epoch,Rmse_test_list)
plt.ylabel("RMSE_train And RMSE_test score")
plt.xlabel("no of epoch")
plt.title("RMSE_train And RMSE_test score vs No of epoch for p = 1")
plt.legend(['Training-score', 'Testing-score'], loc='upper right')
plt.show()
